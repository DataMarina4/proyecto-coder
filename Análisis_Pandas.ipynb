# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/DataMarina4/proyecto-coder/main/Billionaires%20Statistics%20Dataset.csv'
Data_1 = pd.read_csv(url, index_col=0, encoding='UTF-8', sep=',', on_bad_lines='skip')
Data_1
# Out:
#       finalWorth               category                personName   age  \
# rank
# 1         211000       Fashion & Retail  Bernard Arnault & family  74.0
# 2         180000             Automotive                 Elon Musk  51.0
# 3         114000             Technology                Jeff Bezos  59.0
# 4         107000             Technology             Larry Ellison  78.0
# 5         106000  Finance & Investments            Warren Buffett  92.0
# ...          ...                    ...                       ...   ...
# 2540        1000             Healthcare                   Yu Rong  51.0
# 2540        1000        Food & Beverage    Richard Yuengling, Jr.  80.0
# 2540        1000          Manufacturing             Zhang Gongyun  60.0
# 2540        1000            Real Estate    Zhang Guiping & family  71.0
# 2540        1000            Diversified               Inigo Zobel  66.0
#
#             country        city                        source  \
# rank
# ...

# %%
# Datos de las columnas
Data_1.columns
# Out:
# Index(['finalWorth', 'category', 'personName', 'age', 'country', 'city',
#        'source', 'industries', 'countryOfCitizenship', 'organization',
#        'selfMade', 'status', 'gender', 'birthDate', 'lastName', 'firstName',
#        'title', 'date', 'state', 'residenceStateRegion', 'birthYear',
#        'birthMonth', 'birthDay', 'cpi_country', 'cpi_change_country',
#        'gdp_country', 'gross_tertiary_education_enrollment',
#        'gross_primary_education_enrollment_country', 'life_expectancy_country',
#        'tax_revenue_country_country', 'total_tax_rate_country',
#        'population_country', 'latitude_country', 'longitude_country'],
#       dtype='object')

# %%
# Analizamos los datos de Estados Unidos
data_1_usa = Data_1[Data_1['country']=='United States']
data_1_usa
# Out:
#       finalWorth               category              personName   age  \
# rank
# 2         180000             Automotive               Elon Musk  51.0
# 3         114000             Technology              Jeff Bezos  59.0
# 4         107000             Technology           Larry Ellison  78.0
# 5         106000  Finance & Investments          Warren Buffett  92.0
# 6         104000             Technology              Bill Gates  67.0
# ...          ...                    ...                     ...   ...
# 2540        1000                 Energy       George Sakellaris  76.0
# 2540        1000             Technology            Neerja Sethi  68.0
# 2540        1000             Technology             Scott Smith  73.0
# 2540        1000        Food & Beverage     David Tran & family  77.0
# 2540        1000        Food & Beverage  Richard Yuengling, Jr.  80.0
#
#             country           city                      source  \
# rank
# ...

# %%
# Millonarios self-made menores de 50 con final Worth superior a 5000
data_1_usa_sm_50_5000 = data_1_usa[(data_1_usa['selfMade']==1) &(data_1_usa['age']<50) & (data_1_usa['finalWorth']>5000)]
data_1_usa_sm_50_5000
# Out:
#       finalWorth               category           personName   age  \
# rank
# 14         76000             Technology          Sergey Brin  49.0
# 16         64400             Technology      Mark Zuckerberg  38.0
# 113        15500             Technology          Robert Pera  45.0
# 130        13700             Technology             Jan Koum  47.0
# 206         9300             Technology         Brian Chesky  41.0
# 223         8800             Technology     Dustin Moskovitz  38.0
# 239         8500  Finance & Investments  Chase Coleman, III.  47.0
# 261         8000             Technology   Nathan Blecharczyk  39.0
# 290         7600             Technology           Joe Gebbia  41.0
# 466         5500             Technology        John Collison  32.0
# 466         5500             Technology     Patrick Collison  34.0
# 497         5300  Finance & Investments          Todd Boehly  49.0
#
#             country           city               source  \
# rank
# ...
